# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge-Ruiz-Troccoli/Data-Science-I/blob/main/Clase_002/ejemplo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("¡Hola, futuros científicos de datos!")
# Out:
# ¡Hola, futuros científicos de datos!

# %%
print("hola")
# Out:
# hola

# %%
print("hola esta es una mejora")
# Out:
# hola esta es una mejora

# %%
print("hola esta es una mejora número 2")
# Out:
# hola esta es una mejora número 2
