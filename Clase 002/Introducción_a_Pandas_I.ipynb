# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge-Ruiz-Troccoli/Data-Science-I/blob/main/Clase%20002/Introducci%C3%B3n_a_Pandas_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Pandas parte I
# ### Coderhouse - Data Science
# Profe Jorge Ruiz

# %% [markdown]
# Para usar una libreria y sus métodos es necesario instalarla primero. Una vez ha sido instalada es necesario importarla en el notebook en el que se va a usar.<br>
#
# Para importar usamos el comando <code> import </code> seguido del nombre de la libreria, en la mayoria de casos se utiliza la clausula <code> as </code> para asignar un "apodo", usualmente más corto que facilite su uso.

# %%
pip install yellowbrick

# %%
# importar la libreria
import pandas as pd

# %%
list(range(50, 70, 2))
# Out:
# [50, 52, 54, 56, 58, 60, 62, 64, 66, 68]

# %%
Numeros = range(50, 70, 2)
Numeros_serie = pd.Series(Numeros)
Numeros_serie
# Out:
# 0    50
# 1    52
# 2    54
# 3    56
# 4    58
# 5    60
# 6    62
# 7    64
# 8    66
# 9    68
# dtype: int64

# %%
Numeros_serie[1:8]
# Out:
# 1    52
# 2    54
# 3    56
# 4    58
# 5    60
# 6    62
# 7    64
# dtype: int64

# %%
Numeros_serie.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
print(Numeros_serie.values)
# Out:
# [50 52 54 56 58 60 62 64 66 68]

# %%
#una serie de texto
Numeros_en_texto = ['primero','segundo','tercero','cuarto','quinto','sexto','séptimo','octavo','noveno','décimo']
Numeros_serie_texto = pd.Series(Numeros_en_texto)
Numeros_serie_texto
# Out:
# 0    primero
# 1    segundo
# 2    tercero
# 3     cuarto
# 4     quinto
# 5      sexto
# 6    séptimo
# 7     octavo
# 8     noveno
# 9     décimo
# dtype: object

# %%
Numeros
# Out:
# range(50, 70, 2)

# %%
# una serie con index de texto y valores numericos
Numeros_en_texto = ['primero','segundo','tercero','cuarto','quinto','sexto','séptimo','octavo','noveno','décimo']
Numeros_serie_2 = pd.Series(data=Numeros,index=Numeros_en_texto, dtype='int8')
Numeros_serie_2
# Out:
# primero    50
# segundo    52
# tercero    54
# cuarto     56
# quinto     58
# sexto      60
# séptimo    62
# octavo     64
# noveno     66
# décimo     68
# dtype: int8

# %%
# las series pueden contener datos de diferente tipo de formato

# Crear una serie con diferentes tipos de datos
s = pd.Series([1, 2.5, 'tres', True])

s
# Out:
# 0       1
# 1     2.5
# 2    tres
# 3    True
# dtype: object

# %%
s.index=[5,6,8,100]
s
# Out:
# 5         1
# 6       2.5
# 8      tres
# 100    True
# dtype: object

# %%
0#los índices pueden contener diferente tipo de datos, pandas no impone restricciones en estos casos
# 001,022, 3, 4, 9, 01
# Crear una serie con un índice mixto
#s = pd.Series(data=["001","022", "3", "4", "9"], index=['a', 1, 'b', 2, True],dtype=str)
s = pd.Series([1,"022", "3", "4", "9"], index=['a', 1, 'b', 2, True], dtype='str')
s
# Out:
# a         1
# 1       022
# b         3
# 2         4
# True      9
# dtype: object

# %%
modelos = ['A4 3.0 Quattro 4dr manual',
 'A4 3.0 Quattro 4dr auto',
 'A6 3.0 4dr',
 'A6 3.0 Quattro 4dr',
 'A4 3.0 convertible 2dr']
peso = [3583, 3627, 3561, 3880, 3814]
precios = ['$33,430', '$34,480', '$36,640', '$39,640', '$42,490']

# %%
Autos_peso = pd.Series(data=peso,dtype=str, index=modelos)
#Autos_peso = pd.Series(peso,modelos, str)
Autos_precio = pd.Series(precios,modelos)

# %%
Autos_precio
# Out:
# A4 3.0 Quattro 4dr manual    $33,430
# A4 3.0 Quattro 4dr auto      $34,480
# A6 3.0 4dr                   $36,640
# A6 3.0 Quattro 4dr           $39,640
# A4 3.0 convertible 2dr       $42,490
# dtype: object

# %%
Autos_peso
# Out:
# A4 3.0 Quattro 4dr manual    3583
# A4 3.0 Quattro 4dr auto      3627
# A6 3.0 4dr                   3561
# A6 3.0 Quattro 4dr           3880
# A4 3.0 convertible 2dr       3814
# dtype: object

# %%
Autos = pd.DataFrame(Autos_peso,Autos_precio)
Autos
# forma incorrecta de levantar el dataframe
# Out:
#            0
# $33,430  NaN
# $34,480  NaN
# $36,640  NaN
# $39,640  NaN
# $42,490  NaN

# %%
#generamos los Dataframe (df) desde las series
Autos = pd.DataFrame({'Peso':Autos_peso,'Precio':Autos_precio})
Autos
# Out:
#                            Peso   Precio
# A4 3.0 Quattro 4dr manual  3583  $33,430
# A4 3.0 Quattro 4dr auto    3627  $34,480
# A6 3.0 4dr                 3561  $36,640
# A6 3.0 Quattro 4dr         3880  $39,640
# A4 3.0 convertible 2dr     3814  $42,490

# %%
# otra forma de generar el dataframe es primero uniendo las series:

s = pd.concat([Autos_peso, Autos_precio], axis=1)
s
# Out:
#                               0        1
# A4 3.0 Quattro 4dr manual  3583  $33,430
# A4 3.0 Quattro 4dr auto    3627  $34,480
# A6 3.0 4dr                 3561  $36,640
# A6 3.0 Quattro 4dr         3880  $39,640
# A4 3.0 convertible 2dr     3814  $42,490

# %%
# Convertir la serie en un DataFrame
df = s.rename(columns={0: 'Peso_autos', 1: 'Precio'})

df
# Out:
#                           Peso_autos   Precio
# A4 3.0 Quattro 4dr manual       3583  $33,430
# A4 3.0 Quattro 4dr auto         3627  $34,480
# A6 3.0 4dr                      3561  $36,640
# A6 3.0 Quattro 4dr              3880  $39,640
# A4 3.0 convertible 2dr          3814  $42,490

# %%
#otro ejemplo de dataframe

peso= [60,70,80,None,10000]
estaturas= ["1.57", "1.68", "1.75", "1.83", None]

datos_p= pd.DataFrame({"Peso":peso, "Estaturas": estaturas})
datos_p
# Out:
#       Peso Estaturas
# 0     60.0      1.57
# 1     70.0      1.68
# 2     80.0      1.75
# 3      NaN      1.83
# 4  10000.0      None

# %%
2datos_p.index= ['a','b','c','d','e']
datos_p
# Out:
#       Peso Estaturas
# a     60.0      1.57
# b     70.0      1.68
# c     80.0      1.75
# d      NaN      1.83
# e  10000.0      None

# %%
Numeros_serie_2
# Out:
# primero    50
# segundo    52
# tercero    54
# cuarto     56
# quinto     58
# sexto      60
# séptimo    62
# octavo     64
# noveno     66
# décimo     68
# dtype: int8

# %%
# seleccionar usando el índice
Numeros_serie_2[2]
# Out:
# /tmp/ipython-input-1820232195.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Numeros_serie_2[2]
# np.int8(54)

# %%
#Mediante el método loc()

Numeros_serie_2.loc['quinto']
# Out:
# np.int8(58)

# %%
Numeros_serie_2.iloc[2]
# Out:
# np.int8(54)

# %%
#Mediante el método iloc()
Numeros_serie_2.iloc[2:6]
# Out:
# tercero    54
# cuarto     56
# quinto     58
# sexto      60
# dtype: int8

# %%
Numeros_serie_2[2:6]
# Out:
# tercero    54
# cuarto     56
# quinto     58
# sexto      60
# dtype: int8

# %%
datos_p.index= [2,20,5,6,7]
datos_p
# Out:
#        Peso Estaturas
# 2      60.0      1.57
# 20     70.0      1.68
# 5      80.0      1.75
# 6       NaN      1.83
# 7   10000.0      None

# %%
datos_p.iloc[1:3]
# Out:
#     Peso Estaturas
# 20  70.0      1.68
# 5   80.0      1.75

# %%
datos_p.loc[5]
# Out:
# Peso         80.0
# Estaturas    1.75
# Name: 5, dtype: object

# %%
Autos
# Out:
#                            Peso   Precio
# A4 3.0 Quattro 4dr manual  3583  $33,430
# A4 3.0 Quattro 4dr auto    3627  $34,480
# A6 3.0 4dr                 3561  $36,640
# A6 3.0 Quattro 4dr         3880  $39,640
# A4 3.0 convertible 2dr     3814  $42,490

# %%
Autos2=Autos
Autos2["Peso"]=Autos2["Peso"].astype('int32')
Autos2
# Out:
#                            Peso   Precio
# A4 3.0 Quattro 4dr manual  3583  $33,430
# A4 3.0 Quattro 4dr auto    3627  $34,480
# A6 3.0 4dr                 3561  $36,640
# A6 3.0 Quattro 4dr         3880  $39,640
# A4 3.0 convertible 2dr     3814  $42,490

# %%
Autos2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, A4 3.0 Quattro 4dr manual to A4 3.0 convertible 2dr
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Peso    5 non-null      int32
#  1   Precio  5 non-null      object
# dtypes: int32(1), object(1)
# memory usage: 272.0+ bytes

# %%
Autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, A4 3.0 Quattro 4dr manual to A4 3.0 convertible 2dr
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Peso    5 non-null      int32
#  1   Precio  5 non-null      object
# dtypes: int32(1), object(1)
# memory usage: 272.0+ bytes

# %%
Autos["Peso"]
# Out:
# A4 3.0 Quattro 4dr manual    3583
# A4 3.0 Quattro 4dr auto      3627
# A6 3.0 4dr                   3561
# A6 3.0 Quattro 4dr           3880
# A4 3.0 convertible 2dr       3814
# Name: Peso, dtype: object

# %%
Autos.Peso==Autos["Peso"] #son 2 formas de seleccionar columnas de la misma forma
# Out:
# A4 3.0 Quattro 4dr manual    True
# A4 3.0 Quattro 4dr auto      True
# A6 3.0 4dr                   True
# A6 3.0 Quattro 4dr           True
# A4 3.0 convertible 2dr       True
# Name: Peso, dtype: bool

# %%
Autos.loc[Autos.Peso== 3583,'Precio']
# ejemplo cuando tenemos que filtrar por str
#Autos.loc[Autos["Peso"]>= 3600,'Precio']
# Out:
# A4 3.0 Quattro 4dr manual    $33,430
# Name: Precio, dtype: object

# %%
Autos[Autos.Peso== 3583]["Precio"]
# Out:
# A4 3.0 Quattro 4dr manual    $33,430
# Name: Precio, dtype: object

# %%
Autos[Autos.Peso> 3000]["Precio"]
# Out:
# A4 3.0 Quattro 4dr manual    $33,430
# A4 3.0 Quattro 4dr auto      $34,480
# A6 3.0 4dr                   $36,640
# A6 3.0 Quattro 4dr           $39,640
# A4 3.0 convertible 2dr       $42,490
# Name: Precio, dtype: object

# %%
Autos.loc[Autos.Peso== "3583"]
# Out:
#                            Peso   Precio
# A4 3.0 Quattro 4dr manual  3583  $33,430

# %%
Autos["Peso"]= Autos["Peso"].astype("int16")
Autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, A4 3.0 Quattro 4dr manual to A4 3.0 convertible 2dr
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Peso    5 non-null      int16
#  1   Precio  5 non-null      object
# dtypes: int16(1), object(1)
# memory usage: 262.0+ bytes

# %%
1# Autos.loc[Autos["Peso"]>= 3600,'Precio']
#Autos.loc[Autos["Peso"]>= 3600]
Autos.loc[Autos["Peso"]>= 3600] #esto es igual a la primera forma
# Out:
#                          Peso   Precio
# A4 3.0 Quattro 4dr auto  3627  $34,480
# A6 3.0 Quattro 4dr       3880  $39,640
# A4 3.0 convertible 2dr   3814  $42,490

# %%
Autos.Peso.mean()
# Out:
# np.float64(3693.0)

# %%
import numpy as np

np.mean(Autos.Peso)
# Out:
# np.float64(3693.0)

# %%
Autos[Autos.Peso >=3600][["Precio", "otra column"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-476368131.py in <cell line: 0>()
# ----> 1 Autos[Autos.Peso >=3600][["Precio", "otra column"]]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
Autos.columns
# Out:
# Index(['Peso', 'Precio'], dtype='object')

# %%
Autos.values
# Out:
# array([[3583, '$33,430'],
#        [3627, '$34,480'],
#        [3561, '$36,640'],
#        [3880, '$39,640'],
#        [3814, '$42,490']], dtype=object)

# %%
Autos['Peso']
# Out:
# A4 3.0 Quattro 4dr manual    3583
# A4 3.0 Quattro 4dr auto      3627
# A6 3.0 4dr                   3561
# A6 3.0 Quattro 4dr           3880
# A4 3.0 convertible 2dr       3814
# Name: Peso, dtype: int16

# %%
Autos.Peso
# Out:
# A4 3.0 Quattro 4dr manual    3583
# A4 3.0 Quattro 4dr auto      3627
# A6 3.0 4dr                   3561
# A6 3.0 Quattro 4dr           3880
# A4 3.0 convertible 2dr       3814
# Name: Peso, dtype: int16

# %%
Autos["Peso"].loc["A4 3.0 convertible 2dr"]
# Out:
# np.int16(3814)

# %%
Autos.loc[Autos.Peso >= 3600,'Precio']
# Out:
# A4 3.0 Quattro 4dr auto    $34,480
# A6 3.0 Quattro 4dr         $39,640
# A4 3.0 convertible 2dr     $42,490
# Name: Precio, dtype: object

# %%
type(Autos.Precio)
# Out:
# pandas.core.series.Series

# %%
Autos.loc[Autos.Peso >= 3600]["Precio"]
# Out:
# A4 3.0 Quattro 4dr auto    $34,480
# A6 3.0 Quattro 4dr         $39,640
# A4 3.0 convertible 2dr     $42,490
# Name: Precio, dtype: object

# %%
Autos[Autos.Peso >= 3600]["Precio"]
# Out:
# A4 3.0 Quattro 4dr auto    $34,480
# A6 3.0 Quattro 4dr         $39,640
# A4 3.0 convertible 2dr     $42,490
# Name: Precio, dtype: object

# %%
Autos.T
# Out:
#        A4 3.0 Quattro 4dr manual A4 3.0 Quattro 4dr auto A6 3.0 4dr  \
# Peso                        3583                    3627       3561
# Precio                   $33,430                 $34,480    $36,640
#
#        A6 3.0 Quattro 4dr A4 3.0 convertible 2dr
# Peso                 3880                   3814
# Precio            $39,640                $42,490

# %%
Numeros_serie_2
# Out:
# primero    50
# segundo    52
# tercero    54
# cuarto     56
# quinto     58
# sexto      60
# séptimo    62
# octavo     64
# noveno     66
# décimo     68
# dtype: int8

# %%
Numeros = range(30, 50, 2)
Numeros_serie = pd.Series(Numeros)

Numeros_en_texto = ['primeroo','segundo','tercero','cuarto','quinto','sexto','séptimo','octavo','noveno','décimo']
Numeros_serie_3 = pd.Series(Numeros,index=Numeros_en_texto)
Numeros_serie_3
# Out:
# primeroo    30
# segundo     32
# tercero     34
# cuarto      36
# quinto      38
# sexto       40
# séptimo     42
# octavo      44
# noveno      46
# décimo      48
# dtype: int64

# %%
"""
Cuando se suman dos series en Python utilizando el operador +, si una serie tiene un valor NaN (Not a Number) y
la otra serie tiene un valor numérico, el resultado de la suma será NaN.

Esto se debe a que NaN representa una falta de valor o un valor desconocido, y cualquier operación matemática que
involucre NaN dará como resultado NaN. Por lo tanto, cuando se suman dos números, si uno de ellos es NaN, el resultado de
la suma también será NaN.
"""
Numeros_nan=Numeros_serie_2 + Numeros_serie_3
Numeros_nan
# Out:
# cuarto       92.0
# décimo      116.0
# noveno      112.0
# octavo      108.0
# primero       NaN
# primeroo      NaN
# quinto       96.0
# segundo      84.0
# sexto       100.0
# séptimo     104.0
# tercero      88.0
# dtype: float64

# %%
Numeros_serie_2.add(Numeros_serie_3)

#sub resta
# Out:
# cuarto       92.0
# décimo      116.0
# noveno      112.0
# octavo      108.0
# primero       NaN
# primeroo      NaN
# quinto       96.0
# segundo      84.0
# sexto       100.0
# séptimo     104.0
# tercero      88.0
# dtype: float64

# %%
# Crear la serie con el parámetro name y con nombre de índice
serie = pd.Series([10, 20, 30, 40], name='Ejemplo').rename_axis('numeros')

# Asignar un nombre al índice con rename_axis()
#serie = serie.rename_axis('Letras')

# Asignar un nombre a la columna con rename()
#serie = serie.rename('Valores')

# Imprimir la serie
serie
# Out:
# numeros
# 0    10
# 1    20
# 2    30
# 3    40
# Name: Ejemplo, dtype: int64

# %%
Numeros_nan.isnull()
# Out:
# cuarto      False
# décimo      False
# noveno      False
# octavo      False
# primero      True
# primeroo     True
# quinto      False
# segundo     False
# sexto       False
# séptimo     False
# tercero     False
# dtype: bool

# %%
Numeros_nan.isna()
# Out:
# cuarto      False
# décimo      False
# noveno      False
# octavo      False
# primero      True
# primeroo     True
# quinto      False
# segundo     False
# sexto       False
# séptimo     False
# tercero     False
# dtype: bool

# %%
Numeros_nan.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 11 entries, cuarto to tercero
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 9 non-null      float64
# dtypes: float64(1)
# memory usage: 476.0+ bytes

# %%
Numeros_nan.fillna(-999)
#Numeros_nan= Numeros_nan.fillna(-999)
# Out:
# cuarto       92.0
# décimo      116.0
# noveno      112.0
# octavo      108.0
# primero    -999.0
# primeroo   -999.0
# quinto       96.0
# segundo      84.0
# sexto       100.0
# séptimo     104.0
# tercero      88.0
# dtype: float64

# %%
Numeros_nan.fillna(Numeros_nan.mean())
# Out:
# cuarto       92.0
# décimo      116.0
# noveno      112.0
# octavo      108.0
# primero     100.0
# primeroo    100.0
# quinto       96.0
# segundo      84.0
# sexto       100.0
# séptimo     104.0
# tercero      88.0
# dtype: float64

# %%
Numeros_nan=Numeros_nan.dropna()
Numeros_nan
# Out:
# cuarto      92.0
# décimo     116.0
# noveno     112.0
# octavo     108.0
# quinto      96.0
# segundo     84.0
# sexto      100.0
# séptimo    104.0
# tercero     88.0
# dtype: float64

# %%
Numeros_nan.isnull()
# Out:
# cuarto     False
# décimo     False
# noveno     False
# octavo     False
# quinto     False
# segundo    False
# sexto      False
# séptimo    False
# tercero    False
# dtype: bool

# %%
Numeros_nan.isnull().sum()
# Out:
# np.int64(0)

# %%
Numeros_nan.isna().sum()
#puede usar .isna()  o . isnull()
# Out:
# np.int64(0)

# %%
df= pd.read_csv('pokemon_data.txt',delimiter='\t', index_col=0, dtype={'HP':str})
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   HP          800 non-null    object
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(6), object(4)
# memory usage: 69.5+ KB

# %%
df[(df.HP>30)&(df.Attack>80)]
# Out:
#                           Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 3                     Venusaur    Grass  Poison  80      82       83      100
# 3        VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 6                    Charizard     Fire  Flying  78      84       78      109
# 6    CharizardMega Charizard X     Fire  Dragon  78     130      111      130
# 6    CharizardMega Charizard Y     Fire  Flying  78     104       78      159
# ..                         ...      ...     ...  ..     ...      ...      ...
# 719                    Diancie     Rock   Fairy  50     100      150      100
# 719        DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720        HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720         HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721                  Volcanion     Fire   Water  80     110      120      130
#
# ...

# %%
len(df[df["Type 1"]=="Fire"])
# Out:
# 52

# %%
df["peso"]

# %%
df.isnull().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df["Type 2"].fillna("ES DE UN SOLO TIPO", inplace=True)
# Out:
# /tmp/ipython-input-2136170338.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Type 2"].fillna("ES DE UN SOLO TIPO", inplace=True)

# %%
df
# Out:
#                       Name   Type 1              Type 2  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass              Poison  45      49       49
# 2                  Ivysaur    Grass              Poison  60      62       63
# 3                 Venusaur    Grass              Poison  80      82       83
# 3    VenusaurMega Venusaur    Grass              Poison  80     100      123
# 4               Charmander     Fire  ES DE UN SOLO TIPO  39      52       43
# ..                     ...      ...                 ...  ..     ...      ...
# 719                Diancie     Rock               Fairy  50     100      150
# 719    DiancieMega Diancie     Rock               Fairy  50     160      110
# 720    HoopaHoopa Confined  Psychic               Ghost  80     110       60
# 720     HoopaHoopa Unbound  Psychic                Dark  80     160       60
# 721              Volcanion     Fire               Water  80     110      120
#
# ...

# %%
df.index

# %%
df.head(3)
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False

# %%
df.columns

# %%
df.shape
# Out:
# (800, 11)

# %%
df.size
# Out:
# 8800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(7), object(3)
# memory usage: 69.5+ KB

# %%
df['Type 2'].isna().sum()

# %%
df['Type 2'].isnull().sum()

# %%
df['Type 2'].isnull().sum()==df['Type 2'].isna().sum()
