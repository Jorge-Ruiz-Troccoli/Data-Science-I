# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge-Ruiz-Troccoli/Data-Science-I/blob/main/Clase%20006/Analitica_Descriptiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar librerias
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files
import io

# %%
dataset = files.upload()

"""
Cuando subes un archivo utilizando la función files.upload(), el archivo se guarda en formato binario
en la memoria del kernel de Python de Google Colab.
Luego, puedes utilizar la biblioteca io para leer el archivo en una estructura de datos de Python
y manipular los datos según sea necesario.

"""
# Out:
#      <input type="file" id="files-510c064f-ddfd-4c5e-a71d-d47f52365326" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-510c064f-ddfd-4c5e-a71d-d47f52365326">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("bank-full.csv")
df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %%
#Submuestra simple

sub_muestra = df.sample(n=10, random_state=10)
sub_muestra
# Out:
#        age            job   marital  education default  balance housing loan  \
# 4393    55     technician  divorced  secondary      no        0     yes   no
# 4438    31  self-employed    single   tertiary      no     1820     yes   no
# 11108   28     management    single   tertiary      no     2253     yes   no
# 35421   28     technician   married  secondary      no     7449     yes   no
# 2667    43   entrepreneur   married  secondary      no       59      no   no
# 35841   53    blue-collar   married  secondary     yes       20     yes   no
# 27148   45     technician  divorced  secondary      no     1738      no   no
# 2122    48    blue-collar  divorced  secondary      no      602     yes   no
# 40802   20        student    single  secondary      no      130      no   no
# 12882   47     technician    single  secondary      no     -239     yes  yes
#
#          contact day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
#Submuestra 30% de los datos
sub_muestra_30 = df.sample(frac = .30)
len(sub_muestra_30)
# Out:
# 13563

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.marital= df.marital.astype("category")
df.describe(include="category")
# Out:
#         marital
# count     45211
# unique        3
# top     married
# freq      27214

# %%
df.marital.value_counts()
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %%
df.day= df.day.astype("str")

# %%
df.describe()
# Out:
#                 age        balance      duration      campaign         pdays  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058    258.163080      2.763841     40.197828
# std       10.618762    3044.765829    257.527812      3.098021    100.128746
# min       18.000000   -8019.000000      0.000000      1.000000     -1.000000
# 25%       33.000000      72.000000    103.000000      1.000000     -1.000000
# 50%       39.000000     448.000000    180.000000      2.000000     -1.000000
# 75%       48.000000    1428.000000    319.000000      3.000000     -1.000000
# max       95.000000  102127.000000   4918.000000     63.000000    871.000000
#
#            previous
# count  45211.000000
# mean       0.580323
# std        2.303441
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      275.000000

# %%
#podemos calcular la media de una columna o variable
print(df['age'].mean())
print(df['age'].median())


#media > mediana, la distribución es asimétrica con cola a la derecha.
# Out:
# 40.93621021432837
# 39.0

# %%
#Asimetria a la derecha
df['age'].hist()
# Out:
# <Axes: >

# %%
df.balance.hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# Utilice la desviación estándar para determinar qué tan dispersos están los datos con respecto a la media. Un valor de desviación estándar más alto indica una mayor dispersión de los datos.

# %%
##caculando la desviación estandar.

df['age'].std()
# Out:
# 10.618762040975431

# %%
#Se contrasta std con el promedio, para saber si es un std alto o bajo.
df['age'].mean()
# Out:
# np.float64(40.93621021432837)

# %% [markdown]
# Es importante tener en cuenta que la desviación estándar depende de la escala de los datos. En este caso, si la escala de los datos es grande (por ejemplo, si se están midiendo valores en millones), una desviación estándar de 250 podría ser relativamente pequeña en comparación con los valores reales. Por otro lado, si la escala de los datos es pequeña (por ejemplo, si se están midiendo valores en centímetros), una desviación estándar de 250 podría ser relativamente grande en comparación con los valores reales.

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calcular el coeficiente de variación para cada columna
coef_var = (df["age"].std() / df['age'].mean()) *100
coef_var
# Out:
# np.float64(25.939777974998485)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df["age"]=df["age"].fillna(df["age"].mean())
# así es como podemos rellenar los NaN

# %%
df["age"]=df["age"].fillna(df["age"].median())

# %%
for variable in df.select_dtypes(include="number").columns: # hacerla de forma automatizada a todas las variables
    print(variable,(df[variable].std() / df[variable].mean()) *100)

# el CV puede ser muy alto, inclusive superar el 100%. Puede ser por naturaleza propia de la variable o por valores outliers...
# Out:
# age 25.939777974998485
# balance 223.50644366460864
# duration 99.75392782080385
# campaign 112.09115380932653
# pdays 249.08994109011795
# previous 396.9237072927338

# %%
df.pdays.hist()
# Out:
# <Axes: >

# %%
#std de una lista


lista = [12, 24, 36, 48, 60]
print("List : " + str(lista))

st_dev = np.std(lista)
st_dev
# Out:
# List : [12, 24, 36, 48, 60]
# np.float64(16.97056274847714)

# %%
import matplotlib.pyplot as plt
import numpy as np

#Generamos una muestra de 5000 elementos con media 0 y desviación estándar 1
normal_samples = np.random.normal(0, 1, size=5000)

#Graficamos nuestros datos
fig, ax = plt.subplots()
plt.hist(normal_samples, bins=50, density=True)
plt.title('Distribución normal', size=14)
plt.xlabel('Muestras')
plt.ylabel('Densidad')

plt.show()

# %%
df = sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
# Por defecto toma todas las variables identificadas como númericas
# int, float o complex
df.describe().round(1)
# Out:
#          carat    depth    table    price        x        y        z
# count  53940.0  53940.0  53940.0  53940.0  53940.0  53940.0  53940.0
# mean       0.8     61.7     57.5   3932.8      5.7      5.7      3.5
# std        0.5      1.4      2.2   3989.4      1.1      1.1      0.7
# min        0.2     43.0     43.0    326.0      0.0      0.0      0.0
# 25%        0.4     61.0     56.0    950.0      4.7      4.7      2.9
# 50%        0.7     61.8     57.0   2401.0      5.7      5.7      3.5
# 75%        1.0     62.5     59.0   5324.2      6.5      6.5      4.0
# max        5.0     79.0     95.0  18823.0     10.7     58.9     31.8

# %% [markdown]
# No obstante, **no todas** las variables que tienen números son Cuantitativas, por lo que es necesario tener cuidado y considerar el contexto de los datos

# %%
# cuando se aplica sobre variables cualitativas no puede calculas las
# metricas tradicionales, por lo que calcula la cuenta de valores únicos (unique),
# la moda, el valor más frecuente (top)
df.describe(include='category')
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
# Para las variables categoricas es muy común realizar un conteo por categoria
# el método value_counts() permite contar las frecuencias de cada categoria
df.color.value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
df.color.value_counts(normalize=True) # En este caso calcula la proporción sobre el total de observaciones
# Out:
# color
# G    0.209344
# E    0.181628
# F    0.176900
# H    0.153949
# D    0.125603
# I    0.100519
# J    0.052058
# Name: proportion, dtype: float64

# %%
(df.color.value_counts(normalize=True)*100).round(1) # si lo multiplican por 100 esta en porcentaje
# Out:
# color
# G    20.9
# E    18.2
# F    17.7
# H    15.4
# D    12.6
# I    10.1
# J     5.2
# Name: proportion, dtype: float64

# %% [markdown]
# ## Veamos otro caso

# %%
df = sns.load_dataset('mpg')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
type(df.mpg)
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe().round(1)
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# count  398.0      398.0         398.0       392.0   398.0         398.0
# mean    23.5        5.5         193.4       104.5  2970.4          15.6
# std      7.8        1.7         104.3        38.5   846.8           2.8
# min      9.0        3.0          68.0        46.0  1613.0           8.0
# 25%     17.5        4.0         104.2        75.0  2223.8          13.8
# 50%     23.0        4.0         148.5        93.5  2803.5          15.5
# 75%     29.0        8.0         262.0       126.0  3608.0          17.2
# max     46.6        8.0         455.0       230.0  5140.0          24.8
#
#        model_year
# count       398.0
# mean         76.0
# std           3.7
# min          70.0
# 25%          73.0
# 50%          76.0
# 75%          79.0
# max          82.0

# %% [markdown]
# Ven alguna variable que tenga un tipo de dato equivocado??
#
# Para responder esta pregunta nos podemos apoyar en la descripción de la base de datos o en los conocimientos previos del negocio https://archive.ics.uci.edu/ml/datasets/auto+mpg

# %%
# Vamos a cambiar el tipo de esta variable usando el método astype
df['cylinders'] = df['cylinders'].astype('category')

# %%
df.dtypes
# Out:
# mpg              float64
# cylinders       category
# displacement     float64
# horsepower       float64
# weight             int64
# acceleration     float64
# model_year         int64
# origin            object
# name              object
# dtype: object

# %%
df.describe()
# Out:
#               mpg  displacement  horsepower       weight  acceleration  \
# count  398.000000    398.000000  392.000000   398.000000    398.000000
# mean    23.514573    193.425879  104.469388  2970.424623     15.568090
# std      7.815984    104.269838   38.491160   846.841774      2.757689
# min      9.000000     68.000000   46.000000  1613.000000      8.000000
# 25%     17.500000    104.250000   75.000000  2223.750000     13.825000
# 50%     23.000000    148.500000   93.500000  2803.500000     15.500000
# 75%     29.000000    262.000000  126.000000  3608.000000     17.175000
# max     46.600000    455.000000  230.000000  5140.000000     24.800000
#
#        model_year
# count  398.000000
# mean    76.010050
# std      3.697627
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %%
df.describe(include='category')
# Out:
#         cylinders
# count         398
# unique          5
# top             4
# freq          204

# %%
df['cylinders'].nunique()
# Out:
# 5

# %%
df['cylinders'].unique()
# Out:
# [8, 4, 6, 3, 5]
# Categories (5, int64): [3, 4, 5, 6, 8]

# %%
# el método value_counts() permite contar las frecuencias de cada categoria
df['cylinders'].value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
# si utilizamos el parametro normalize se obtienen los datos
# con frecuencia relativa o porcentaje
df['cylinders'].value_counts(normalize=True)*100
# Out:
# cylinders
# 4    51.256281
# 8    25.879397
# 6    21.105528
# 3     1.005025
# 5     0.753769
# Name: proportion, dtype: float64

# %%
# el ID de los autos esta almacenado en el index, lo vamos a extraer y renombrar para poder comprobar su cardinalidad
df.reset_index(inplace=True)
df.rename(columns={'index':'ID'}, inplace=True)

#df=df.rename(columns={'index':'ID'}) equivalente
# Para evaluar la cardinalidad de las variables podemos utilizar nunique()
# Este método cuenta los valores únicos de una variable
df.nunique()
# Out:
# ID              398
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %%
df

# %% [markdown]
# Cuando la cardinalidad de una variable sea igual a la cantidad de filas, estamos tratando con un ID. <br>

# %%
# Tambien se puede utilizar en una columna única
df.origin.nunique()

# %%
# y tl método unique() muestra los datos únicos
df.origin.unique()

# %%
df.origin.value_counts()

# %% [markdown]
# medidas de resumen

# %%
promedio = df.acceleration.mean() # promedio o media
mediana = df.acceleration.median() # mediana o Q2
moda = df.acceleration.mode() # moda

primer_cuartil = df.acceleration.quantile(0.25) # Q1 cuartíl 1 --> percentíl 25
tercer_cuartil = df.acceleration.quantile(0.75) # Q3 cuartíl 3 --> percentíl 75
segundo_cuartil = df.acceleration.quantile(0.50) #Q2
percentil_99 = df.acceleration.quantile(0.99) # percentíl 99
percentil_01 = df.acceleration.quantile(0.01) # percentíl 1


# Imprimir los resultados
print("Promedio: ", promedio)
print("Mediana: ", mediana)
print("segundo cuartil: ", segundo_cuartil)
print("Moda: ", moda)
print("Primer cuartil: ", primer_cuartil)
print("Tercer cuartil: ", tercer_cuartil)
print("Percentil 99: ", percentil_99)
print("Percentil 1: ", percentil_01)

#outlier superior:                                    #IQR
print("outlier superior: ", tercer_cuartil+1.5*(tercer_cuartil-primer_cuartil))
print("outlier inferior", primer_cuartil-1.5*(tercer_cuartil-primer_cuartil))
# Out:
# Promedio:  15.568090452261307
# Mediana:  15.5
# segundo cuartil:  15.5
# Moda:  0    14.5
# Name: acceleration, dtype: float64
# Primer cuartil:  13.825000000000001
# Tercer cuartil:  17.175
# Percentil 99:  22.238999999999965
# Percentil 1:  9.485
# outlier superior:  22.2
# outlier inferior 8.8

# %%
df[(df.acceleration>=tercer_cuartil+1.5*(tercer_cuartil-primer_cuartil)) |  (df.acceleration<=primer_cuartil-1.5*(tercer_cuartil-primer_cuartil))]
# Out:
#       mpg cylinders  displacement  horsepower  weight  acceleration  \
# 7    14.0         8         440.0       215.0    4312           8.5
# 9    15.0         8         390.0       190.0    3850           8.5
# 11   14.0         8         340.0       160.0    3609           8.0
# 59   23.0         4          97.0        54.0    2254          23.5
# 195  29.0         4          85.0        52.0    2035          22.2
# 299  27.2         4         141.0        71.0    3190          24.8
# 300  23.9         8         260.0        90.0    3420          22.2
# 326  43.4         4          90.0        48.0    2335          23.7
# 394  44.0         4          97.0        52.0    2130          24.6
#
#      model_year  origin                               name
# 7            70     usa                  plymouth fury iii
# 9            70     usa                 amc ambassador dpl
# 11           70     usa                 plymouth 'cuda 340
# ...

# %%
df[(df.acceleration>=22.2) |  (df.acceleration<=8.8)]
# Out:
#       ID   mpg cylinders  displacement  horsepower  weight  acceleration  \
# 7      7  14.0         8         440.0       215.0    4312           8.5
# 9      9  15.0         8         390.0       190.0    3850           8.5
# 11    11  14.0         8         340.0       160.0    3609           8.0
# 59    59  23.0         4          97.0        54.0    2254          23.5
# 195  195  29.0         4          85.0        52.0    2035          22.2
# 299  299  27.2         4         141.0        71.0    3190          24.8
# 300  300  23.9         8         260.0        90.0    3420          22.2
# 326  326  43.4         4          90.0        48.0    2335          23.7
# 394  394  44.0         4          97.0        52.0    2130          24.6
#
#      model_year  origin                               name
# 7            70     usa                  plymouth fury iii
# 9            70     usa                 amc ambassador dpl
# 11           70     usa                 plymouth 'cuda 340
# ...

# %%
df_sin_outliers=df[~((df.acceleration>=tercer_cuartil+1.5*(tercer_cuartil-primer_cuartil)) |(df.acceleration<=primer_cuartil-1.5*(tercer_cuartil-primer_cuartil)))]

# %%
df_sin_outliers
# Out:
#       ID   mpg cylinders  displacement  horsepower  weight  acceleration  \
# 0      0  18.0         8         307.0       130.0    3504          12.0
# 1      1  15.0         8         350.0       165.0    3693          11.5
# 2      2  18.0         8         318.0       150.0    3436          11.0
# 3      3  16.0         8         304.0       150.0    3433          12.0
# 4      4  17.0         8         302.0       140.0    3449          10.5
# ..   ...   ...       ...           ...         ...     ...           ...
# 392  392  27.0         4         151.0        90.0    2950          17.3
# 393  393  27.0         4         140.0        86.0    2790          15.6
# 395  395  32.0         4         135.0        84.0    2295          11.6
# 396  396  28.0         4         120.0        79.0    2625          18.6
# 397  397  31.0         4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# ...
